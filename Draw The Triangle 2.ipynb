# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-19 13-10-20.png")

# %% [markdown]
# **set @number = 0;
# select repeat('* ', @number := @number + 1) from information_schema.tables where @number < 20;**
