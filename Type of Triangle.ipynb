# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 07-57-26.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 07-57-49.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 07-58-08.png")

# %% [markdown]
# ### select case when A + B > C
# ### then case
# ### when A = B and B = C then "Equilateral"
# ### when A = B or B = C or A = C then "Isosceles"
# ### when A != B or B != C or A != C then "Scalene"
# ### END
# ### else "Not A Triangle"
# ### END from triangles;
