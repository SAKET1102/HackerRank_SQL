# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 09-09-09.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 09-09-27.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 09-09-50.png")

# %% [markdown]
# ### select (salary * months)as earnings ,count(*) from employee group by 1 order by earnings desc limit 1;

# %% [markdown]
# ### SELECT MAX(months * salary) ||' '|| COUNT(*) FROM employee GROUP BY salary HAVING MAX(months * salary) = (SELECT MAX(months * salary) from employee);
