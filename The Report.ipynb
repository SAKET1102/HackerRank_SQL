# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 09-08-22.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 09-08-44.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 09-09-02.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 09-09-17.png")

# %% [markdown]
# **select if(grade < 8 ,null,name),grade ,marks from students JOIN GRADES <br>
# WHERE MARKS BETWEEN MIN_MARK AND MAX_MARK <br>
# ORDER BY GRADE DESC, NAME;**
