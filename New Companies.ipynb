# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-18 20-04-13.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-18 20-04-34.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-18 20-04-55.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-18 20-05-19.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-18 20-05-36.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-18 20-05-54.png")

# %% [markdown]
# __select A.company_code,A.founder,count( distinct B.lead_manager_code),count(distinct <br > C.Senior_manager_code),count(distinct D.manager_code), <br >
# count(distinct E.employee_code) from <br >
# Company A,<br >
# Lead_Manager B,<br >
# Senior_Manager C,<br >
# Manager D,<br >
# Employee E<br >
# where A.company_code = B.company_code<br >
# and B.company_code = C.company_code<br >
# and C.company_code = D.company_code<br >
# and E.company_code = E.company_code<br >
# and B.lead_manager_code = C.lead_manager_code<br >
# and D.lead_manager_code = E.lead_manager_code<br >
# and C.senior_manager_code = D.senior_manager_code<br >
# and D.senior_manager_code = E.senior_manager_code<br >
# and D.manager_code = E.manager_code<br >
# group by A.company_code ,A.founder<br >
# order by A.company_code; __<br >
