# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 08-56-54.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 08-57-15.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 08-57-32.png")

# %% [markdown]
# ### select CEIL(AVG(salary) - AVG(Replace(salary,0,''))) from EMPLOYEES;
