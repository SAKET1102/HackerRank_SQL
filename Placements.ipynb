# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 10-28-22.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 10-28-48.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 10-29-07.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-20 10-29-22.png")

# %% [markdown]
# **select B.name from packages C, students B, friends A, (select salary,id from packages) E where <br>
# A.ID = B.ID and A.ID = C.ID and E.ID = A.Friend_ID and C.salary < E.salary order by E.salary;**
