# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-19 13-09-37.png")

# %% [markdown]
# **set @number = 21;
# select repeat('* ', @number := @number - 1) from information_schema.tables;**
