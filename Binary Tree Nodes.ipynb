# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 08-08-34.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 08-09-10.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 08-09-30.png")

# %% [markdown]
# **select N,case <br>
# when p is Null then 'Root' <br>
# when n in (select p from bst) then 'Inner' <br>
# else 'Leaf' <br>
# end as node <br>
# from BST <br>
# order by n;**
